# %%
import json
from collections import Counter
from dataclasses import asdict
from functools import reduce, partial
from typing import List, Set

import numpy as np
from more_itertools import minmax
from nltk import word_tokenize
from scipy.spatial.distance import cosine
from scipy.special import softmax
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import normalize
from tqdm import tqdm

from src.clustering import embeddings
from src.clustering.embeddings.params import Params
from src.clustering.embeddings.tokenizer import Tokenizer
from src.clustering.keyword import KeywordGroup
from src.settings import DATA_PATH, MODELS_PATH
from src.utils import file_paths
from src.utils.merge_csv import merge

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model_params = dict(
    eps=0.08,
    min_samples=2,
    metric='cosine'
)

# %%
params = Params(
    v='1.8.5',
    group_fn='weighted sum',
    model='DBSCAN',
    model_params=model_params
)

# %%
df = merge(file_paths(DATA_PATH / 'raw' / 'data_validation'), columns_take=3)

# %%
keywords: List[Set[str]] = (
    df
        .keywords_processed
        .dropna()
        .map(lambda s: s.split(','))
        .tolist()
)

# %%
tokenizer = Tokenizer(
    embeddings
        .get_source('ruwiki')
        .load(MODELS_PATH / 'embeddings')
)
# Out:
# [INFO] loading projection weights from D:\projects\rpd-keyword-extraction\models\embeddings\ruwikiruscorpora_upos_cbow_300_10_2021\model.bin
# [INFO] KeyedVectors lifecycle event {'msg': 'loaded (249333, 300) matrix of type float32 from D:\\projects\\rpd-keyword-extraction\\models\\embeddings\\ruwikiruscorpora_upos_cbow_300_10_2021\\model.bin', 'binary': True, 'encoding': 'utf8', 'datetime': '2022-03-29T19:42:29.003790', 'gensim': '4.1.2', 'python': '3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'load_word2vec_format'}
# c:\users\uiqko\pyenvs\mint\lib\site-packages\gensim\models\keyedvectors.py:478: UserWarning: Adding single vectors to a KeyedVectors which grows by one each time can be costly. Consider adding in batches or preallocating to the required size.
#   warnings.warn(

# %%
all_keywords = set(map(str.strip, reduce(list.__add__, keywords)))

# %%
counter = Counter(
    reduce(
        list.__add__,
        map(tokenizer.tokenize, all_keywords)
    )
)
counter[tokenizer.default_index] = 1

# %%
all_keywords = set(all_keywords)
# todo??/
all_keywords.remove('')
all_keywords.remove(' ')

# %%
def keyword_to_embeddings(keyword: str):
    embeddings = tokenizer.vectorize(
        tokenizer.tokenize(keyword), to=np.array)

    return embeddings

# %%
mn, mx = minmax(counter.values())
m = mx - mn

def normalize_(x):
    return np.array([(x_ - mn) / m for x_ in x])

# %%
def keyword_to_embedding(keyword: str):  # 'w1 w2 ... wn'
    indexes = tokenizer.tokenize(keyword)
    counts = list(map(counter.get, indexes))
    # vec = 1 - softmax(normalize([counts]))[0]
    vec = 1 - normalize_(counts)
    embeddings = keyword_to_embeddings(keyword)  # n x 300

    return embeddings.T @ vec  # 300 x 1

# %%
model = DBSCAN(**model_params)

# %%
keyword_by_embedding = {}
embedding_by_keyword = {}
X = []

for keyword in tqdm(all_keywords, desc='Embeddings'):
    embedding = keyword_to_embedding(keyword)
    embedding_key = tuple(embedding)
    # todo +0.001 if key in dict
    keyword_by_embedding[embedding_key] = keyword
    embedding_by_keyword[keyword] = embedding
    X.append(embedding)

model.fit_predict(X)
# Out:
# Embeddings: 100%|██████████| 11301/11301 [00:11<00:00, 945.69it/s]
# array([ -1,  -1,   0, ...,  -1,  -1, 699], dtype=int64)

# %%
groups = {}
other = []

for i, label in enumerate(model.labels_):
    if label == -1:
        other.append(keyword_by_embedding[tuple(X[i])])
    else:
        groups.setdefault(label, set())\
            .add(keyword_by_embedding[tuple(X[i])])

# %%
def keyword_group_center(kws: List[str]) -> str:
    keyword_embeddings = list(map(embedding_by_keyword.get, kws))
    center = np.mean(keyword_embeddings, axis=0)
    nearest = min(keyword_embeddings, key=partial(cosine, center))
    return keyword_by_embedding[tuple(nearest)]

# %%
def most_common_group_center(kws: List[str]) -> str:
    return ', '.join(dict(Counter(word_tokenize(' '.join(kws))).most_common(2)).keys())

# %%
keyword_groups = [
    KeywordGroup(most_common_group_center(kws), kws)
    for kws in groups.values()
]

# %%
keyword_groups
# Out:
# [KeywordGroup(mean='полевые, транзисторы', keywords={'полевые транзисторы'}),
#  KeywordGroup(mean='переменные', keywords={'переменные'}),
#  KeywordGroup(mean='линеаризация, динамической', keywords={'линеаризация динамической модели электропривода', ' линеаризация динамической модели'}),
#  KeywordGroup(mean='действия, принципы', keywords={' принципы действия устройств', 'физические принципы действия', ' принцип действия', ' принципы действия оборудования', ' принцип действия преобразователей', ' физические принципы действия устройств', ' принцип действия приборов'}),
#  KeywordGroup(mean='maps', keywords={' maps'}),
#  KeywordGroup(mean='скорость, распространения', keywords={'скорость распространения'}),
#  KeywordGroup(mean='материалов, свойства', keywords={' анализ свойств материалов', ' исследования теплофизических свойств материалов', 'расчет термодинамическим методом', ' термодинамические методы расчета свойств материалов', ' физикохимические свойства материала', 'свойства полимерных материалов', ' теплофизические свойства материалов', 'методы расчета свойств материалов', ' свойства материалов', ' свойства пищевых материалов', ' термодинамические методы расчета свойств', ' свойства конструкционных материалов'}),
#  KeywordGroup(mean='виртуальная, реальность', keywords={'виртуальная реальность', 'технологии виртуальной реальности'}),
#  KeywordGroup(mean='износостойкость', keywords={' износостойкость'}),
#  KeywordGroup(mean='измерения, методы', keywords={'теплофизические измерения', 'спектрометрические методы измерения', ' теория квантовых измерений', 'формализм квантовой теории', 'оптические измерения', 'оптические методы измерения', 'квантовые измерения', 'методы измерений', ' линейноугольные измерения', 'квантовая теория', ' теории оптических измерений', ' методы оптических измерений'}),
#  KeywordGroup(mean='память', keywords={'память'}),
#  KeywordGroup(mean='итеративное, обучение', keywords={'итеративное обучение', ' системы обучения'}),
#  KeywordGroup(mean='функций, численные', keywords={'численное дифференцирование функций', 'численные методы аппроксимации функции', 'численные методы дифференцирования и интегрирования функций', ' численные методы апроксимации табличных функций'}),
#  KeywordGroup(mean='предприятия', keywords={' предприятия'}),
#  KeywordGroup(mean='защита, гидросферы', keywords={'защита гидросферы'}),
#  KeywordGroup(mean='информационных, систем', keywords={' внедрение инновационных информационных систем', ' методологии внедрения информационных систем'}),
#  KeywordGroup(mean='эксперимент', keywords={'эксперимент'}),
#  KeywordGroup(mean='социальная, психология', keywords={'социальная психология малых групп', 'социальная психология групп'}),
#  KeywordGroup(mean='статическое, тестирование', keywords={' статическое тестирование', ' системное статическое тестирование'}),
#  KeywordGroup(mean='юридические, аспекты', keywords={' юридические аспекты интеллектуальной деятельности'}),
#  KeywordGroup(mean='волны, монохроматические', keywords={' волны', ' рлоские монохроматические волны', 'фракталы волны', ' монохроматические волны'}),
#  KeywordGroup(mean='экспериментальная, физика', keywords={' экспериментальная физика'}),
#  KeywordGroup(mean='нейронные, сети', keywords={'нейронные сети', ' рекуррентные нейронные сети', ' оптимизация для нейронных сетей', ' свёрточные нейронные сети'}),
#  KeywordGroup(mean='identification, presentation', keywords={' presentation identification', ' scenarios identification'}),
#  KeywordGroup(mean='эффективность, вычислительных', keywords={' эффективность вычислительных алгоритмов', ' эффективность вычислительных схем'}),
#  KeywordGroup(mean='методы, анализа', keywords={'методы анализа моделирования бизнеспроцессов', ' моделирование систем холодоснабжения', 'моделирование в blender', 'методы анализа', 'методы точностного анализа', 'анализ', ' моделирование САПР', ' анализ фурье', ' формализованные методы анализа', ' точностный анализ', 'методы моделирования'}),
#  KeywordGroup(mean='of, systems', keywords={'indicators of manufacturability', 'equilibrium positions of dynamic systems', 'functions of complex variable', 'functioning of instruments and devices', 'theory of functions of complex', 'mechanical models of fabrics', 'optimization of neural network hyperparameters', 'quality indicators of optoelectronic devices', ' effectiveness of lighting solution', 'tuning of neural networks', ' automated design of optical', ' numerical methods of solving ode', '  computer modelling of optical', ' methods of solving pde', 'equilibrium positions of dynamic', 'features of application', 'basics of scaling', ' identification of performance characteristics', 'quantum statistics of social systems', ' calculation of optical systems'}),
#  KeywordGroup(mean='критерий, гурвица', keywords={' критерий гурвица'}),
#  KeywordGroup(mean='теория, информации', keywords={' теория информации', ' квантовая теория информации'}),
#  KeywordGroup(mean='автоматизированные, информационно-управляющие', keywords={'автоматизированные информационно-управляющие системы'}),
#  KeywordGroup(mean='архитектуры, вычислительной', keywords={' основ архитектуры вычислительной техники', ' архитектуры вычислительной техники'}),
#  KeywordGroup(mean='анализа, текстовых', keywords={'анализа текстовых данных', 'инструментарий анализа текстовых данных'}),
#  KeywordGroup(mean='задач, решения', keywords={' основные методы решения математических', 'Решение логических задач', ' основные методы решения математических задач', 'решение измерительных задач', ' способы решения задач', ' методы решения задач математического анализа', 'вероятностные методы решения задач', 'теория решения изобретательских задач', ' алгоритм решения изобретательских задач', ' решение оптических задач', ' методы решения математических задач', ' решение изобретательских задач', ' симплекс метод решения задач', 'решение задач'}),
#  KeywordGroup(mean='light, optics', keywords={' light optics', ' interferometry light', ' light fields', ' light waves', ' composition light', ' polarizing light phenomena'}),
#  KeywordGroup(mean='данных, базы', keywords={'база данных', ' референсные базы данных', 'нереляционные базы данных', ' документирования баз данных', ' распределённые базы данных', ' реляционная база данных'}),
#  KeywordGroup(mean='задачи, задач', keywords={'задача кластеризации', 'задачи', ' декомпозиция задач', ' распределенные задачи', 'задачи моделирования', 'анализ задач'}),
#  KeywordGroup(mean='исследования, методы', keywords={' теоретические основы научного исследования', ' теплофизические исследования', ' методы научных исследований', ' классификация научных исследований', ' аналитическое исследование', 'общенаучные методы исследования', 'методология научных исследований', 'методы исследования систем холодоснабжения', 'математическое моделирование в научных исследованиях', ' системный подход в научных исследованиях', 'научные исследования', ' использование методов научного исследования', 'научный анализ', ' исследование', ' теоретические методы научного исследования', ' выбор методов научных исследований', ' эргономическое исследование', ' генномные методы исследования', ' исследование транскриптома', 'цифровые научные исследования', ' особенности научного исследования', ' теоретические предпосылки научных исследований', 'методы исследования', ' взможности аналитических методов исследования', ' аналитические методы исследования'}),
#  KeywordGroup(mean='политики, информационной', keywords={' анализ политики информационной безопасности', ' документирование политики информационной безопасности'}),
#  KeywordGroup(mean='кубизм', keywords={' кубизм'}),
#  KeywordGroup(mean='библиотека, numpy', keywords={' библиотека numpy'}),
#  KeywordGroup(mean='лазер, лазеры', keywords={'инжекционный лазер', ' титансапфировый лазер', 'волоконные лазеры', ' накачка твердотельных лазеров', 'диодные лазеры'}),
#  KeywordGroup(mean='структуры, структура', keywords={'корпускулярная структура', ' структуры биомолекул', ' низкоразмерные структуры наносистем', ' анизотропные структуры', ' структура биомехатронной системы'}),
#  KeywordGroup(mean='of, human', keywords={' sensitivity of human contrast', ' physiology of human visual acuity', ' stereoscopic of human binocularand'}),
#  KeywordGroup(mean='инновационное, производство', keywords={' инновационное производство', ' инновационное развитие высокотехнологичных производств'}),
#  KeywordGroup(mean='алгебраические, методы', keywords={' алгебраические и геометрические методы анализа', 'алгебраические методы анализа', 'алгебраические методы анализа геометрии', ' алгебраические методы в  анализе геометрии', ' анализ геометрии'}),
#  KeywordGroup(mean='исследования, рынка', keywords={' методы исследования рынка инноваций', ' процесс исследования рынка инноваций', ' методы исследования рынков', ' исследования анализа на рынке инноваций', 'Исследование рынка', 'методология исследования рынка инноваций'}),
#  KeywordGroup(mean='модель, максвелла', keywords={' модель максвелла', ' модель osi', 'модели инфокоммуникационных систем'}),
#  KeywordGroup(mean='данных, характеристика', keywords={'характеристика реляционной модели данных', 'реляционная модель данных'}),
#  KeywordGroup(mean='мониторинг, глобальных', keywords={'мониторинг глобальных технологических трендов', ' глобальные технологические тренды'}),
#  KeywordGroup(mean='отзыв, руководителя', keywords={'отзыв руководителя'}),
#  KeywordGroup(mean='колоночная, субд', keywords={' колоночная субд'}),
#  KeywordGroup(mean='тепловой, баланс', keywords={'тепловой баланс'}),
#  KeywordGroup(mean='анализ, данных', keywords={' анализ размерености данных', ' анализ данных'}),
#  KeywordGroup(mean='термодинамический, цикл', keywords={' термодинамический цикл холодильной машины', ' термодинамические циклы машин'}),
#  KeywordGroup(mean='функциональной, структуры', keywords={' выбор функциональной структуры', ' обоснование выбора функциональной структуры'}),
#  KeywordGroup(mean='подгонка, микросхем', keywords={' подгонка микросхем', ' микросхемы'}),
#  KeywordGroup(mean='сигналы, срнс', keywords={'сигналы срнс'}),
#  KeywordGroup(mean='data, formation', keywords={'data formation', 'environment data', 'data driven', ' protein data', 'data application', 'holography data'}),
#  KeywordGroup(mean='комплексные, исследования', keywords={'комплексные исследования'}),
#  KeywordGroup(mean='аналитическая, механика', keywords={'аналитическая механика'}),
#  KeywordGroup(mean='безопасность', keywords={' безопасность'}),
#  KeywordGroup(mean='типовая, структура', keywords={'типовая структура устройства интернета вещей'}),
#  KeywordGroup(mean='квантовые, методы', keywords={' квантовые ямы сверхрешеток', 'квантовая электродинамика', ' квантовый ротатор', 'квантовые методы', 'квантовые квантовоподобные методы'}),
#  KeywordGroup(mean='металлы, пайка', keywords={' металлы', 'пайка металлов'}),
#  KeywordGroup(mean='макет', keywords={' макет'}),
#  KeywordGroup(mean='виды, Виды', keywords={'Виды резьб', ' виды сегментации', ' виды локомоции'}),
#  KeywordGroup(mean='фильтрация, коллаборативная', keywords={' фильтрация', ' коллаборативная фильтрация'}),
#  KeywordGroup(mean='управление, проектами', keywords={'управление проектами реинжиниринга', ' модели инновационных проектов', ' управление проектами', ' коммерлизация инновационного проекта', 'инновационные проекты', '  управление инновационными проектами', ' технология управления проектом', ' проектирование инновационных проектов'}),
#  KeywordGroup(mean='компоненты, архитектурные', keywords={' архитектурные компоненты', ' компоненты архитектурной системы'}),
#  KeywordGroup(mean='оптимизация, одд', keywords={' оптимизация одд', 'многокритериальная оптимизация'}),
#  KeywordGroup(mean='излучение, приемники', keywords={' фемтосекундное излучение', 'терагерцовое излучение', ' оптическое излучение', ' многоэлементные приемники оптического излучения', 'Излучение', ' лазерное излучение', ' приемники оптического излучения'}),
#  KeywordGroup(mean='management, strategic', keywords={'strategic management', ' devices management', 'management', 'operational management', ' product management'}),
#  KeywordGroup(mean='инструменты, данных', keywords={'инструменты анализа данных', ' инструменты для обработки данных', 'инструмент визуализации данных', ' инструменты обработки информации'}),
#  KeywordGroup(mean='кластеризация', keywords={'кластеризация'}),
#  KeywordGroup(mean='имитационное, моделирование', keywords={'вероятностное имитационное моделирование', 'имитационное моделирование'}),
#  KeywordGroup(mean='задание, на', keywords={' задание на вкр'}),
#  KeywordGroup(mean='термодинамика', keywords={'  термодинамика'}),
#  KeywordGroup(mean='усилители, малошумящие', keywords={' усилители', 'малошумящие усилители'}),
#  KeywordGroup(mean='php', keywords={' php'}),
#  KeywordGroup(mean='объектов, многопоточные', keywords={' детектирование объектов', ' многопоточные объекты software transactional', ' трекинг объектов', ' патентоспособности объектов', ' многопоточные объекты'}),
#  KeywordGroup(mean='постановка, задачи', keywords={' постановка задач оптимизации', ' постановка задачи', ' постановка формулировки задачи'}),
#  KeywordGroup(mean='стандартизация', keywords={'стандартизация'}),
#  KeywordGroup(mean='of, the', keywords={' systems of the lighting', ' evaluation of the sustainability', ' segmentation of the target audience', ' spectral sensitivity of the eye'}),
#  KeywordGroup(mean='эмоционального, интеллекта', keywords={'Модели эмоционального интеллекта', ' эмоциональный интеллект', ' основные модели эмоционального интеллекта'}),
#  KeywordGroup(mean='передаточная, функция', keywords={' передаточная функция'}),
#  KeywordGroup(mean='отладка', keywords={'отладка'}),
#  KeywordGroup(mean='methods, in', keywords={'quantum methods in statistical microeconomics', 'approximate methods in physics', 'quantum theory methods in economic'}),
#  KeywordGroup(mean='организация, производства', keywords={'организация планирования производства', 'организация технологичекого производства', 'организация производства'}),
#  KeywordGroup(mean='взаимодействие, наноструктур', keywords={'взаимодействие наноструктур', ' электрофотонное взаимодействие'}),
#  KeywordGroup(mean='аналитическая, геометрия', keywords={'аналитическая геометрия'}),
#  KeywordGroup(mean='архитектура, микропроцессоров', keywords={' архитектура микропроцессоров', 'архитектура микроконтроллера'}),
#  KeywordGroup(mean='эффективности, проекта', keywords={' оценка эффективности проекта', ' оценки эффективности научноисследовательских проектов', ' анализ эффективности проекта'}),
#  KeywordGroup(mean='требованиями, совершенствование', keywords={'\nсовершенствование процессов работы требованиями', '\nтребованиями совершенствование процессов работы требованиями'}),
#  KeywordGroup(mean='компоненты, КФС', keywords={' высокоуровневые компоненты КФС', 'компоненты мэмс', ' низкоуровневые компоненты КФС'}),
#  KeywordGroup(mean='лазерная, резка', keywords={' лазерная резка'}),
#  KeywordGroup(mean='документация, разработка', keywords={' проектная документация', ' разработка проектной документации', ' нормативная документация', ' нормативная техническая документация ', 'техническая документация', ' разработка проектноконструкторской документации', ' разработка технической документации', 'технические разработки'}),
#  KeywordGroup(mean='научнотехнической, информации', keywords={' научнотехнической информации', 'фактографическая информация'}),
#  KeywordGroup(mean='методы, бухгалтерского', keywords={'принципы методы бухгалтерского учета', 'принципы методы бухгалтерского', 'методы бухгалтерского учета', 'Бухгалтерский учет'}),
#  KeywordGroup(mean='применение, технологий', keywords={' применение цифровых технологий', ' применение информационных цифровых технологий в оптике', ' применение информационных технологий'}),
#  KeywordGroup(mean='история, развития', keywords={' история развития робототехники', ' история развития'}),
#  KeywordGroup(mean='идентификация', keywords={'   идентификация'}),
#  KeywordGroup(mean='оптическая, связь', keywords={' оптическая связь'}),
#  KeywordGroup(mean='методики, разработки', keywords={' основные методики разработки предметноориентированных онтологий', ' существующие методики разработки онтологий', ' методики разработки предметноориентированных онтологий', 'методики разработки', 'методики разработки онтологий', ' разработка методики исследований'}),
#  KeywordGroup(mean='цифровая, обработка', keywords={' цифровая обработка видеосигнала', 'цифровая обработка'}),
#  KeywordGroup(mean='архитектура, интернет', keywords={' архитектура интернет вещей'}),
#  KeywordGroup(mean='система, абстракций', keywords={' система абстракций архитектурного проектирования', ' архитектурные абстракции'}),
#  KeywordGroup(mean='алгоритмы, числовые', keywords={' числовые алгоритмы', 'алгоритмы кластеризации', ' алгоритмы трекинга', 'нейросетевые алгоритмы', ' строковые алгоритмы'}),
#  KeywordGroup(mean='области, применения', keywords={' области применения методов анализа', '\nобласти их применения', ' области применения'}),
#  KeywordGroup(mean='производства, технологические', keywords={' технологические процессы производства', ' проектирование процессов производства', ' технологические процессы производства продуктов'}),
#  KeywordGroup(mean='разрабатывать, управляющие', keywords={'разрабатывать управляющие программы cam системах', ' разработка управляющих программ'}),
#  KeywordGroup(mean='models, continuous', keywords={'models quantum strategies decision making', ' sketch models', 'models rating', 'models basics', 'models stability', 'models using equilibrium', 'creating models continuous mathematical models', 'continuous mathematical models', 'models analytical', 'diseases models', 'models dependency'}),
#  KeywordGroup(mean='секвенирование, таргетное', keywords={' таргетное секвенирование', ' секвенирование рнк', ' методы секвенирования', 'секвенирование днк'}),
#  KeywordGroup(mean='датчики', keywords={' датчики'}),
#  KeywordGroup(mean='измерительная, локационная', keywords={'измерительная локационная система', ' измерительные системы'}),
#  KeywordGroup(mean='математические, алгоритмы', keywords={' математические алгоритмы', ' математические алгоритмы сегментации'}),
#  KeywordGroup(mean='in, the', keywords={'  lighting prototypessolutions in the environment', 'the mathematical apparatus in epidemiology'}),
#  KeywordGroup(mean='культурные, различия', keywords={' культурные различия', ' конфессиональные культурные различия'}),
#  KeywordGroup(mean='спектры, поглощения', keywords={'спектры поглощения'}),
#  KeywordGroup(mean='оборудование, для', keywords={'\nоборудование для очистки сырья полуфабрикатов', '\nоборудование для очистки сырья'}),
#  KeywordGroup(mean='негативные, факторы', keywords={'негативные факторы техносферы', ' негативные факторы'}),
#  KeywordGroup(mean='методы, структурного', keywords={' методы структурного функционального моделирования', 'Функциональные структурные системы', ' функциональное моделирование'}),
#  KeywordGroup(mean='контроль, качества', keywords={'  контроль качества сырья'}),
#  KeywordGroup(mean='верификация', keywords={'верификация'}),
#  KeywordGroup(mean='nonline, properties', keywords={' nonline properties'}),
#  KeywordGroup(mean='метрология', keywords={' метрология'}),
#  KeywordGroup(mean='обработка, воздуха', keywords={'термоэлектрическая обработка воздуха', 'тепловлажностная обработка воздуха'}),
#  KeywordGroup(mean='литография', keywords={'литография'}),
#  KeywordGroup(mean='бактериологические, лаборатории', keywords={' бактериологические лаборатории'}),
#  KeywordGroup(mean='самофокусировка, света', keywords={' самофокусировка света', 'свет'}),
#  KeywordGroup(mean='расчёт, точностные', keywords={' расчёт', 'точностные расчеты', 'методы расчета роялти'}),
#  KeywordGroup(mean='лазерного, излучения', keywords={' сферы применения лазерного излучения', ' применение лазерного излучения'}),
#  KeywordGroup(mean='прогнозирование, результата', keywords={'прогнозирование результата'}),
#  KeywordGroup(mean='эволюционные, алгоритмы', keywords={'эволюционные алгоритмы', 'гибридные эволюционные алгоритмы'}),
#  KeywordGroup(mean='математических, моделей', keywords={'построение математических моделей систем', 'математическая модель', ' адекватность математической модели', 'анализ математических моделей', ' построение математических моделей', ' математические модели анализа данных', ' анализ математических моделей систем управления'}),
#  KeywordGroup(mean='развития, стратегии', keywords={' выбор стратегии развития', ' принципы разработки стратегии развития систем', 'стратегия развития'}),
#  KeywordGroup(mean='решений, принятия', keywords={' теория принятия решений', ' принятие управленческих решений', ' многокритериальные методы принятия управленческих решений', 'принятие решений теории управления', ' теории принятия управленческих решений'}),
#  KeywordGroup(mean='динамические, системы', keywords={' динамические системы'}),
#  KeywordGroup(mean='очереди', keywords={'очереди'}),
#  KeywordGroup(mean='свойства, оптических', keywords={'поляризационные свойства', 'оптический элемент', ' компрессионные свойства', ' центрировка оптических элементов', 'оптические свойства систем устройств оптоинформатики', ' лазерные элементы систем', ' оптические лазерные элементы', ' структурномеханические свойства', 'Оптические свойства', ' свойства оптических элементов'}),
#  KeywordGroup(mean='данных, динамические', keywords={' динамические структуры данных', 'структур данных\n'}),
#  KeywordGroup(mean='характеристики, Проектно-конструкторские', keywords={'Проектно-конструкторские характеристики', 'точностные характеристики'}),
#  KeywordGroup(mean='решение, систем', keywords={'решение систем линейных уравнений'}),
#  KeywordGroup(mean='пространство, конфигурационное', keywords={' конфигурационное пространство', ' евклидово пространство'}),
#  KeywordGroup(mean='разработка, оптического', keywords={' разработка оптического прибора'}),
#  KeywordGroup(mean='биотехнологическое, производство', keywords={'биотехнологическое производство', ' промышленные биотехнологические производства'}),
#  KeywordGroup(mean='фирменный, стиль', keywords={' фирменный стиль'}),
#  KeywordGroup(mean='хранение, видеоинформации', keywords={' хранение видеоинформации', ' хранение'}),
#  KeywordGroup(mean='верные, рассуждения', keywords={'верные рассуждения'}),
#  KeywordGroup(mean='анализ, проблемы', keywords={' анализ проблемы'}),
#  KeywordGroup(mean='теория, вероятностей', keywords={' теория вероятностей'}),
#  KeywordGroup(mean='фармацептическая, токсикология', keywords={' фармацептическая токсикология'}),
#  KeywordGroup(mean='температур, получение', keywords={' получение низких температур', ' методы получения низких температур', ' получение сверхнизких температур'}),
#  KeywordGroup(mean='последовательностная, логика', keywords={' последовательностная логика'}),
#  KeywordGroup(mean='ректификация', keywords={' ректификация'}),
#  KeywordGroup(mean='методы, последовательной', keywords={' методы последовательной оптимизации'}),
#  KeywordGroup(mean='явления, полупроводниках', keywords={'явления полупроводниках', ' кинетические явления в полупроводниках'}),
#  KeywordGroup(mean='электрическая, машина', keywords={' электрическая машина'}),
#  KeywordGroup(mean='технологии, бионические', keywords={' бионические технологии', ' инфокоммуникативные технологии', ' технологии наноматериалов'}),
#  KeywordGroup(mean='комплементарность, азотистых', keywords={' комплементарность азотистых оснований', 'азотистые основания'}),
#  KeywordGroup(mean='иновационная, деятельность', keywords={'иновационная деятельность', ' системы анализа деятельности'}),
#  KeywordGroup(mean='управления, робастное', keywords={'управления', ' робастное управление', ' распределенная система управления'}),
#  KeywordGroup(mean='физические, принципы', keywords={' физические принципы'}),
#  KeywordGroup(mean='теплофизических, процессов', keywords={'процессы анализа теплофизических процессов в природе', 'анализ теплофизических процессов в природе', 'основы природы теплофизических процессов', ' основы природы теплофизических процессов для анализа', ' физические основы природы теплофизических процессов', 'процессы для анализа теплофизических процессов природы', 'теплофизические процессы в природе', ' выявление взаимосвязи теплофизических процессов в природе'}),
#  KeywordGroup(mean='идеи', keywords={' идеи'}),
#  KeywordGroup(mean='мотивация', keywords={' мотивация'}),
#  KeywordGroup(mean='оптические, кристаллы', keywords={' оптические кристаллы'}),
#  KeywordGroup(mean='защита, от', keywords={' защита от маскирования', ' защита', 'методы защиты'}),
#  KeywordGroup(mean='первобытный, мир', keywords={' первобытный мир'}),
#  KeywordGroup(mean='технологии, диагностики', keywords={'технологии сетевой диагностики', ' технологии диагностики'}),
#  KeywordGroup(mean='динамика', keywords={'динамика'}),
#  KeywordGroup(mean='изображений, обработки', keywords={'обработки изображений matlab', '\nобработка изображений системе matlab', ' методы анализа и обработки изображений', 'обработка цветных изображений'}),
#  KeywordGroup(mean='классификация, оптических', keywords={' классификация оптических приборов', ' классификация оптических датчиков', ' классификация оптико-электронных приборов'}),
#  KeywordGroup(mean='плотности, матрицы', keywords={' матрицы плотности', ' редуцированная матрица плотности', ' формализм матриц плотности', 'свойства матрицы плотности'}),
#  KeywordGroup(mean='дисперсия', keywords={' дисперсия'}),
#  KeywordGroup(mean='структура, хорошей', keywords={'структура хорошей истории'}),
#  KeywordGroup(mean='амплитуда', keywords={'амплитуда'}),
#  KeywordGroup(mean='цели, формулирование', keywords={' цели', ' формулирование цели', ' цели по SMART'}),
#  KeywordGroup(mean='данных, анализ', keywords={'анализ защиты данных', 'защита данных'}),
#  KeywordGroup(mean='полупроводниковые, диоды', keywords={'полупроводниковый лазера', ' полупроводниковые лазерные диоды', ' полупроводниковые диоды'}),
#  KeywordGroup(mean='долговечность', keywords={' долговечность'}),
#  KeywordGroup(mean='применение, методов', keywords={' применение методов анализа', ' корректное применение методов анализа', ' применения голографии', 'применение биотехнических систем', 'применение низкоуровневых методов', ' применение'}),
#  KeywordGroup(mean='документирование', keywords={'документирование'}),
#  KeywordGroup(mean='методы, астрономогеодезический', keywords={' астрономогеодезический и инерциальногеодезический методы', ' детерминистические методы'}),
#  KeywordGroup(mean='хлебобулочные, изделия', keywords={'сдобные хлебобулочные изделия', 'слоеные хлебобулочные изделия', '  хлебобулочное изделие'}),
#  KeywordGroup(mean='экологическое, законодательство', keywords={' экологическое законодательство'}),
#  KeywordGroup(mean='обеспечения, программного', keywords={'оптическое программное обеспечение', ' программное обеспечение', 'документационного сопровождения разработки программного обеспечения', ' средства проектирования программного обеспечения', ' программное информационное обеспечение', 'программное обеспечение расчета оптических систем', 'разработки программного обеспечения документирование', 'сопровождения разработки программного обеспечения', 'системное программное обеспечение', ' самостоятельная разработка программных программноаппаратных средств', 'методы средства проектирования программного обеспечения', ' программные технологии обеспечения иб', ' программные средства для проектирования мэмс', ' проектирование программного обеспечения', ' принципы разработки системного программного обеспечения', ' программные средства проектирования', ' методы разработки программных программноаппаратных средств', ' разработка программного обеспечения', ' специализированное программное обеспечение', ' методологии разработки программного обеспечения'}),
#  KeywordGroup(mean='электрические, измерения', keywords={'электрические методы измерения', ' электрические измерения'}),
#  KeywordGroup(mean='подготовка, массового', keywords={' подготовка массового мероприятия'}),
#  KeywordGroup(mean='контроль, межведомвственный', keywords={' межведомвственный контроль', ' контроль управления', ' методы контроля', ' автоматизированный контроль'}),
#  KeywordGroup(mean='дипломатические, отношения', keywords={' дипломатические отношения в европе', ' дипломатические отношения'}),
#  KeywordGroup(mean='mapping, limit', keywords={'mapping limit', 'mapping'}),
#  KeywordGroup(mean='механика', keywords={'механика'}),
#  KeywordGroup(mean='design, product', keywords={'design', ' design issues', ' product design methods', 'UI design', ' situation design', ' product design', ' design systems', 'design thinking'}),
#  KeywordGroup(mean='волноклассическая, теория', keywords={' волноклассическая теория', ' теории нечетких систем', 'Теория тепломассообмена'}),
#  KeywordGroup(mean='коммутация', keywords={'коммутация'}),
#  KeywordGroup(mean='документация, нормативно-техническая', keywords={' нормативно-техническая документация', '\nпредпроектная документация', 'проектно-конструкторская документация'}),
#  KeywordGroup(mean='тип, данных', keywords={'тип данных'}),
#  KeywordGroup(mean='видео, компьютерное', keywords={'видео компьютерное зрение реальном времени'}),
#  KeywordGroup(mean='распространения, излучения', keywords={'распространения излучения'}),
#  KeywordGroup(mean='роботизированные, системы', keywords={'роботизированные системы'}),
#  KeywordGroup(mean='technique, crystallography', keywords={' technique crystallography'}),
#  KeywordGroup(mean='Биомехатронные, модули', keywords={'Биомехатронные модули', ' мехатронный модуль'}),
#  KeywordGroup(mean='sharp', keywords={'sharp'}),
#  KeywordGroup(mean='уравнение, движения', keywords={' уравнение движения'}),
#  KeywordGroup(mean='компоненты, информационные', keywords={' информационные компоненты', ' компоненты информационной системы'}),
#  KeywordGroup(mean='физические, процессы', keywords={'физические процессы'}),
#  KeywordGroup(mean='автоматизация, управления', keywords={' автоматизация управления проектированием', ' автоматизация проектирования', ' автоматизация систем управления', ' автоматизация проектирования оптических систем', ' автоматизация управления', ' проектирование оптических систем'}),
#  KeywordGroup(mean='математический, аппарат', keywords={' математический аппарат', ' математический аппарат моделирования'}),
#  KeywordGroup(mean='автоматизированное, проектирование', keywords={'автоматизированные системы проектирования', 'автоматизированное проектирование', ' автоматизированное проектирование ис'}),
#  KeywordGroup(mean='оптика, фемтосекундная', keywords={'фемтосекундная оптика', ' поляризационная оптика', ' неизображающая оптика'}),
#  KeywordGroup(mean='закон, стефана', keywords={' закон стефана больцмана', ' закон эшби', ' законы моргана', ' закон ламберта'}),
#  KeywordGroup(mean='кинетика', keywords={' кинетика'}),
#  KeywordGroup(mean='микроскопия', keywords={' микроскопия'}),
#  KeywordGroup(mean='научный, стиль', keywords={' научный стиль документа', ' документы научного стиля'}),
#  KeywordGroup(mean='визуализация, методы', keywords={'визуализация', ' методы визуализации'}),
#  KeywordGroup(mean='проектирование, систем', keywords={' проектирование инфокоммуникационных систем', ' проектирование ис', ' проектирование оптоэлектронных систем', 'проектирование cad'}),
#  KeywordGroup(mean='визуализация, данных', keywords={' визуализация данных'}),
#  KeywordGroup(mean='программирования, языка', keywords={' современные объектноориентированные языки программирования', ' семантика языка программирования python', ' процедурный язык программирования', ' нововведение языка программирования kotlin', ' синтаксис языка python', 'языки программирования', ' синтаксис языка программирования', 'фреймворк языка программирования', ' язык python', ' функциональные языки программирования', ' парадигма языка программирования'}),
#  KeywordGroup(mean='архитектуры, распределенные', keywords={'распределенные архитектуры ис', ' архитектуры по', ' архитектура tcp'}),
#  KeywordGroup(mean='устройства, усилительнопреобразовательные', keywords={'усилительнопреобразовательные устройства', ' мехатронное устройство', ' устройства ввода-вывода'}),
#  KeywordGroup(mean='средства, разработки', keywords={'средства разработки', 'иперспективные средства разработки'}),
#  KeywordGroup(mean='инструменты, digitalмаркетинга', keywords={'\nинструменты digitalмаркетинга оффлайн', 'инструменты digitalмаркетинга онлайн'}),
#  KeywordGroup(mean='фотонные, кристаллы', keywords={'фотонные кристаллы', ' кремниевые фотонные кристаллы'}),
#  KeywordGroup(mean='пучки, гауссовые', keywords={' гауссовые пучки', ' гомоцентрические пучки', 'перетяжка пучком'}),
#  KeywordGroup(mean='нелинейная, оптика', keywords={' нелинейная оптика'}),
#  KeywordGroup(mean='пожарная, безопасность', keywords={' пожарная безопасность'}),
#  KeywordGroup(mean='добычи, нефти', keywords={' автоматизация добычи нефти', ' моделирование добычи нефти'}),
#  KeywordGroup(mean='квантовая, оптика', keywords={'квантовая оптика'}),
#  KeywordGroup(mean='методы, моделирования', keywords={'математические методы', 'математические преобразовани', 'методы компьютерного моделирования', ' методы математического моделирования теплофизических процессов', ' математическое компьютерное моделирование мэмс', ' математический анализ', 'математическое моделирование', ' методы математического компьютерного', ' методы математического моделирования', ' методы математического компьютерного моделирования', ' компьютерное моделирование'}),
#  KeywordGroup(mean='технологии, информационные', keywords={' информационные технологии', ' цифровые информационные технологии', 'оптические информационные технологии', 'цифровые технологии'}),
#  KeywordGroup(mean='единоборство', keywords={' единоборство'}),
#  KeywordGroup(mean='проектируемых, объектов', keywords={'компьютерные модели проектируемых объектов', ' модели проектируемых объектов', ' схемы проектируемых объектов', '\nрасчетных схем проектируемых объектов модели', ' математические компьютерные модели проектируемых объектов'}),
#  KeywordGroup(mean='защиты, информации', keywords={' методы защиты информации', ' средства защиты программного обеспечения', 'защита информации', ' защита технических средств', ' аппаратные средства защиты', 'Средства защиты информации', ' анализ программноаппаратных средств защиты информации', ' программноаппаратные криптографические средства защиты информации', ' обеспечения технической защиты информации', 'средства технической защиты информации', 'современные средства криптографической защиты информации', 'на защиту информации', ' защита программного обеспечения', ' способы средства технической защиты информации', 'системы инженернотехнической защиты информации', ' аппаратные средства защиты информации', ' методы обеспечения программной защиты', 'реализации программноаппаратных средств защиты информации', 'обеспечение программной защиты', ' защита информации в автоматизированных системах'}),
#  KeywordGroup(mean='построение, цифровых', keywords={' построение цифровых устройств', ' цифровое устройство'}),
#  KeywordGroup(mean='классификация, всс', keywords={' классификация всс'}),
#  KeywordGroup(mean='ключей, квантовое', keywords={'квантовое распределение ключей', ' основы квантового распределения ключей'}),
#  KeywordGroup(mean='апертурные, антенны', keywords={'апертурные антенны', 'антенна'}),
#  KeywordGroup(mean='исследования, технологии', keywords={' технологии маркетингового исследования', ' маркетинговое исследования'}),
#  KeywordGroup(mean='молекулярная, физика', keywords={'молекулярная физика'}),
#  KeywordGroup(mean='нанотехнологии', keywords={' нанотехнологии'}),
#  KeywordGroup(mean='принципы, разработки', keywords={' фундаментальные принципы разработки webприложений', 'принципы разработки webприложений'}),
#  KeywordGroup(mean='качества, разработки', keywords={' повышение качества разработки', ' методы повышения качества разработки'}),
#  KeywordGroup(mean='организация, управления', keywords={' организация систем управления', ' организация управления'}),
#  KeywordGroup(mean='сетевые, модели', keywords={'сетевые модели'}),
#  KeywordGroup(mean='сапр', keywords={' сапр'}),
#  KeywordGroup(mean='экономическая, оценка', keywords={'экономическая эффективность', 'оценка экономической эффективности', ' экономическая оценка'}),
#  KeywordGroup(mean='сырье, экстрагента', keywords={' сырье экстрагента', ' контаминанты сырья', ' сырье '}),
#  KeywordGroup(mean='работа, библиотеками', keywords={'работа библиотеками pandas numpy', 'работа библиотекой sklearn'}),
#  KeywordGroup(mean='основы, теоретические', keywords={' теоретические основы сенсорного анализа', ' теоретические основы анализа', ' основы конструирования', ' теоретические основы', 'теоретические основы конструирования оптикоцифровых систем'}),
#  KeywordGroup(mean='современные, бизнесприложения', keywords={' современные бизнесприложения'}),
#  KeywordGroup(mean='инженерного, анализа', keywords={' инженерный анализ', ' системы инженерного анализа', ' методы инженерного анализа'}),
#  KeywordGroup(mean='ресурсами, подсистема', keywords={'подсистема управления ресурсами', ' управление ресурсами микроконтроллеров'}),
#  KeywordGroup(mean='программы, научного', keywords={' программы научного исследования'}),
#  KeywordGroup(mean='схемы, оптимизационные', keywords={' оптимизационные схемы', ' схема бернулли', 'оптические схемы', 'модели схем', ' схемы оптоэлектронных систем'}),
#  KeywordGroup(mean='жизненый, цикл', keywords={' жизненый цикл по'}),
#  KeywordGroup(mean='адаптивный, наблюдатель', keywords={' адаптивный наблюдатель'}),
#  KeywordGroup(mean='протоколы, протокол', keywords={' протокол http', 'телемеханические протоколы', ' протоколы для веба', 'протоколы'}),
#  KeywordGroup(mean='полосковые, волноводы', keywords={' полосковые волноводы'}),
#  KeywordGroup(mean='станции, компрессорные', keywords={' компрессорные станции', ' газораспределительные станции'}),
#  KeywordGroup(mean='педагогика', keywords={'педагогика'}),
#  KeywordGroup(mean='производства, технологии', keywords={' технология производства заквасок', '  автоматизированные технологии производств', 'технология производства', ' технологии производства фотовольтаических систем', ' малоотходные технологии производства'}),
#  KeywordGroup(mean='разработка, мобильная', keywords={'мобильная разработка', ' разработка мобильных приложений'}),
#  KeywordGroup(mean='ток, постоянный', keywords={' постоянный ток', ' переменный ток', ' постоянный переменный ток'}),
#  KeywordGroup(mean='окружающая, среда', keywords={' окружающая среда', 'квазимногоуровневые среды'}),
#  KeywordGroup(mean='динамические, нагрузки', keywords={' динамические нагрузки', ' моделирование динамических нагрузок'}),
#  KeywordGroup(mean='материалов, оптические', keywords={'обработка оптических материалов', ' оптические материалы технологий', 'технологии обработки материалов', ' технология обработки оптических материалов', 'полимеры как оптические материалы', ' обработка материалов', ' оптические материалы'}),
#  KeywordGroup(mean='экологический, менеджмент', keywords={'экологический менеджмент'}),
#  KeywordGroup(mean='сложноизобразительная, композиция', keywords={' сложноизобразительная композиция'}),
#  KeywordGroup(mean='основы, управления', keywords={' основы управления рисками иб', 'концептуальные основы управления рисками иб', ' математические основы управления рисками иб', ' теоретические основы управления рисками'}),
#  KeywordGroup(mean='промышленная, сеть', keywords={' промышленная сеть'}),
#  KeywordGroup(mean='понятие, реинжиниринга', keywords={' понятие реинжиниринга бизнеспроцессов', 'понятия вискозиметриии', ' понятие ис'}),
#  KeywordGroup(mean='динамическое, программирование', keywords={' динамическое программирование'}),
#  KeywordGroup(mean='авторское, право', keywords={' авторское право'}),
#  KeywordGroup(mean='данных, обработка', keywords={' первичная обработка хранение данных', ' обработка и хранение данных', 'обработка хранение данных', 'системы обработки данных', 'методы хранения данных', ' первичная обработка данных', 'обработки данных', 'хранение данных'}),
#  KeywordGroup(mean='научной, работы', keywords={' выполнение научной работы', ' логикометодологические основы выполнения научной работы'}),
#  KeywordGroup(mean='construction, networks', keywords={'networks construction', 'construction features'}),
#  KeywordGroup(mean='манипуляторы, мехатронных', keywords={' манипуляторы', ' манипуляторы мехатронных систем'}),
#  KeywordGroup(mean='производственный, контроль', keywords={'производственный контроль', ' организационная система производственного контроля', 'экоаналитический производственный контроль'}),
#  KeywordGroup(mean='запросы, http', keywords={' http запросы', ' запросы'}),
#  KeywordGroup(mean='история, История', keywords={' история', 'История россии'}),
#  KeywordGroup(mean='о, распространении', keywords={'  задачи о распространении световых волн', 'постановки задач о распространении световых волн'}),
#  KeywordGroup(mean='оптическая, диагностика', keywords={'оптическая диагностика'}),
#  KeywordGroup(mean='машины, виртуальные', keywords={' виртуальные машины', ' устройство виртуальной машины'}),
#  KeywordGroup(mean='математика', keywords={' математика'}),
#  KeywordGroup(mean='лингвистический, текстовый', keywords={' лингвистический текстовый процессор', 'лингвистические процессоры'}),
#  KeywordGroup(mean='стандарт, iso', keywords={' стандарт iso', 'стандарты'}),
#  KeywordGroup(mean='термодинамические, процессы', keywords={' термодинамические процессы', 'термодинамические тепломассообменные процессы'}),
#  KeywordGroup(mean='анализ, технологических', keywords={'технологические инновации', 'анализ технологических инноваций', ' анализ технологических инноваций иктсекторе'}),
#  KeywordGroup(mean='интерполяция', keywords={' интерполяция'}),
#  KeywordGroup(mean='автоматизированные, системы', keywords={'автоматизированные системы управления'}),
#  KeywordGroup(mean='объекты, изобретений', keywords={' объекты изобретений'}),
#  KeywordGroup(mean='физических, величин', keywords={' системы физических величин их единиц', ' внесистемные единицы физических величин'}),
#  KeywordGroup(mean='тензор, тензора', keywords={' ортогональный тензор', ' изотропные тензоры', ' транспонирование тензора', ' тензор', ' инварианты тензора'}),
#  KeywordGroup(mean='оптимизация, программного', keywords={' оптимизация программного кода', 'программный код'}),
#  KeywordGroup(mean='применение, методов', keywords={' применение методов решения', ' разработка и применение методов решения', ' выбор и применение методов решения'}),
#  KeywordGroup(mean='управления, блок-схема', keywords={'блок-схема алгоритма управления', ' алгоритмы управления'}),
#  KeywordGroup(mean='средств, выбор', keywords={' выбор технические средств', ' алгоритмы выбора средств измерений', ' выбор средств измерения', ' выбор технических средств измерения'}),
#  KeywordGroup(mean='методы, автоматизации', keywords={' методы автоматизации', 'автоматизация бизнеспроцессов'}),
#  KeywordGroup(mean='систематизация', keywords={' систематизация'}),
#  KeywordGroup(mean='нормы, правовых', keywords={'анализ правовых норм', ' этические нормы', ' системы правовых норм', ' правовые нормы', ' этические правовые нормы'}),
#  KeywordGroup(mean='построение, моделей', keywords={'построение моделей', 'трехмерные модели', 'построение трехмерных моделей'}),
#  KeywordGroup(mean='подпись, электронно', keywords={'электронно цифровая подпись', '  электронная подпись', ' цифровые подписи'}),
#  KeywordGroup(mean='преобразование, фурье', keywords={'преобразование фурье', ' аналогово-цифровое преобразование'}),
#  KeywordGroup(mean='методы, сбора', keywords={' методы сбора', ' сбор'}),
#  KeywordGroup(mean='мехатронных, устройств', keywords={' построение мехатронных устройств робототехники', ' методы построения мехатронных устройств робототехники'}),
#  KeywordGroup(mean='поля, электромагнитные', keywords={'электромагнитные поля свч', ' разпределение электромагнитного поля'}),
#  KeywordGroup(mean='цифровая, модель', keywords={' цифровая модель производства', ' цифровое производство'}),
#  KeywordGroup(mean='программная, защита', keywords={'программная защита'}),
#  KeywordGroup(mean='интегральнооптические, модуляторы', keywords={' интегральнооптические модуляторы'}),
#  KeywordGroup(mean='теория, множеств', keywords={' теория множеств', 'теория нечетких множеств логики'}),
#  KeywordGroup(mean='инструменты, исследования', keywords={'инструменты исследования'}),
#  KeywordGroup(mean='энергии, неуглеводородные', keywords={' неуглеводородные источники энергии', ' источник энергии'}),
#  KeywordGroup(mean='WEB', keywords={'WEB'}),
#  KeywordGroup(mean='уравнение, состояния', keywords={' уравнение состояния идеального газа'}),
#  KeywordGroup(mean='методы, управления', keywords={'методы управления', 'методы бессенсорного управления'}),
#  KeywordGroup(mean='транкинговые, системы', keywords={' транкинговые системы связи'}),
#  KeywordGroup(mean='биполярный, транзистор', keywords={' биполярный транзистор', 'транзисторы'}),
#  KeywordGroup(mean='этапы, реализации', keywords={' методы этапы реализации киберфизических систем', 'этапы реализации киберфизических систем'}),
#  KeywordGroup(mean='продвижение', keywords={' продвижение'}),
#  KeywordGroup(mean='качества, показатели', keywords={' показатели качества', ' показатели качества мехатронных систем', 'показатели качества мехатронных робототехнических систем', ' анализ показателей качества'}),
#  KeywordGroup(mean='технологии, создания', keywords={'технологии создания интерференционных покрытий'}),
#  KeywordGroup(mean='квантовая, статистика', keywords={'квантовая статистика'}),
#  KeywordGroup(mean='технологии, физического', keywords={'технологии физического канального уровня'}),
#  KeywordGroup(mean='solutions, simulator', keywords={'solutions simulator multi component', '  prototypes solutions', ' lighting solutions'}),
#  KeywordGroup(mean='вещества, маркерные', keywords={' маркерные вещества', 'подслащивающие вещества'}),
#  KeywordGroup(mean='нелинейные, уравнения', keywords={' нелинейные волновые уравнения', 'нелинейные уравнения', ' волновое уравнение'}),
#  KeywordGroup(mean='оценка, качества', keywords={' оценка качества', ' оценка качества модели'}),
#  KeywordGroup(mean='принципы, построения', keywords={' принципы построения сетей', ' принципы построения сетей связи', ' принципы построения инфокоммуникационных сетей'}),
#  KeywordGroup(mean='принципы, инфокоммуникационной', keywords={'\nпринципы', 'принципы инфокоммуникационной системы', ' принцип solid'}),
#  KeywordGroup(mean='сферы, применения', keywords={'сферы применения искусственного интеллекта', '\nзнает сферы применения искусственного интеллекта'}),
#  KeywordGroup(mean='финансового, обеспечения', keywords={'финансового обеспечения инновационной деятельности', 'финансового обеспечения инновационной'}),
#  KeywordGroup(mean='производства, схемы', keywords={' проектирование технологических схем производства', 'схемы биотехнологического производства', ' технологические схемы производства'}),
#  KeywordGroup(mean='слау, методы', keywords={' итерационные методы решения слау', 'решение слау', ' методы решения слау'}),
#  KeywordGroup(mean='анализ, рисков', keywords={'анализ неопределенности рисков', ' анализ рисков'}),
#  KeywordGroup(mean='алгебра, тензорная', keywords={' тензорная алгебра', ' метода алгебры', 'алгебра'}),
#  KeywordGroup(mean='коммуникативный, акт', keywords={'коммуникативный акт'}),
#  KeywordGroup(mean='взаимодействие, электромагнитных', keywords={' взаимодействие электромагнитных волн с веществом', ' взаимодействие электромагнитных волн'}),
#  KeywordGroup(mean='поле', keywords={' поле'}),
#  KeywordGroup(mean='расчёт, характеристик', keywords={' динамические характеристики', ' расчёт динамических характеристик', 'расчёт характеристик'}),
#  KeywordGroup(mean='эффективности, оценка', keywords={' оценка эффективности', ' методы оценки эффективности результатов'}),
#  KeywordGroup(mean='javascript', keywords={' javascript'}),
#  KeywordGroup(mean='нормативноправовые, документы', keywords={' нормативноправовые документы', ' верстка документов'}),
#  KeywordGroup(mean='Детали, оптических', keywords={'Детали оптических систем', ' оптические детали'}),
# ...
#  KeywordGroup(mean='анализ, моделей', keywords={' анализ моделей'}),
#  KeywordGroup(mean='теплофизика', keywords={'теплофизика'}),
#  KeywordGroup(mean='исследование, функций', keywords={' исследование функций'}),
#  KeywordGroup(mean='финансовое, планирование', keywords={' финансовое планирование'}),
#  KeywordGroup(mean='and, integral', keywords={'transformations and integral equations', 'metrics and scoring functions', ' reflection and refraction', 'integral transformations and integral equations', ' setting goal and defining tasks', ' strengths and', ' transformation evolution and transition', 'classical and quantum noises'}),
#  KeywordGroup(mean='виды, интеллекта', keywords={' виды интеллекта'}),
#  KeywordGroup(mean='квантовая, информатика', keywords={' квантовая информатика'}),
#  KeywordGroup(mean='форматы, кураторства', keywords={'форматы кураторства', ' форматы сторителлинга'}),
#  KeywordGroup(mean='кодирование, информации', keywords={' кодирование информации', '\nсоматическое кодирование информации'}),
#  KeywordGroup(mean='случайные, события', keywords={' случайные события'}),
#  KeywordGroup(mean='построение, изображения', keywords={' построение изображения'}),
#  KeywordGroup(mean='процессы, управления', keywords={' процессы управления рисками'}),
#  KeywordGroup(mean='качество', keywords={' качество'}),
#  KeywordGroup(mean='планирование, методы', keywords={'планирование', ' методы планирования'}),
#  KeywordGroup(mean='баланс, энтропийный', keywords={'энтропийный баланс', ' баланс'}),
#  KeywordGroup(mean='структурные, схемы', keywords={' структурные функциональные схемы', ' структурная схема считывателя', ' структурные схемы', ' принципы построения функциональных схем скуд', ' функциональная схема'}),
#  KeywordGroup(mean='навигация', keywords={' навигация'}),
#  KeywordGroup(mean='state, types', keywords={'  state types', ' state'}),
#  KeywordGroup(mean='работа, пользователей', keywords={'работа пользователей'}),
#  KeywordGroup(mean='инновационной, продукции', keywords={' проведение испытаний инновационной продукции и планирование', ' испытания инновационной продукции индустрии', ' оборудования для испытания инновационной продукции', 'испытания инновационной продукции планирование', ' осуществление испытаний инновационной продукции', ' испытания инновационной продукции'}),
#  KeywordGroup(mean='корректные, вычисления', keywords={'корректные вычисления'}),
#  KeywordGroup(mean='целостность, данных', keywords={'целостность данных'}),
#  KeywordGroup(mean='компиляция', keywords={'компиляция'}),
#  KeywordGroup(mean='конфигурациями, электронного', keywords={' методы управления конфигурациями электронного изделия', ' управление конфигурациями электронного изделия'}),
#  KeywordGroup(mean='быстрое, прототипирование', keywords={' быстрое прототипирование'}),
#  KeywordGroup(mean='полупроводники', keywords={' полупроводники'}),
#  KeywordGroup(mean='электроприводы', keywords={'электроприводы'}),
#  KeywordGroup(mean='Wi-Fi, Mesh-сети', keywords={' Wi-Fi Mesh-сети'}),
#  KeywordGroup(mean='методы, логического', keywords={' методы логического доказательства', ' логическое доказательство'}),
#  KeywordGroup(mean='конструкции, турбомашин', keywords={' конструкции турбомашин', ' изоляционные конструкции'}),
#  KeywordGroup(mean='systems, control', keywords={'convergence control methods', ' systems designing', ' optical systems', ' composite systems', ' control systems'}),
#  KeywordGroup(mean='промышленных, технологий', keywords={' перспективы развития промышленных технологий', ' развитие промышленных технологий'}),
#  KeywordGroup(mean='микропроцессорная, техника', keywords={' микропроцессорная техника'}),
#  KeywordGroup(mean='программа, отладка', keywords={'программа', ' отладка программы', ' распараллеливание программ'}),
#  KeywordGroup(mean='построение, систем', keywords={' построение оптикоцифровых систем', ' методы построения анализаторных систем', 'построение видеосистем'}),
#  KeywordGroup(mean='основы, материаловедения', keywords={'основы материаловедения'}),
#  KeywordGroup(mean='операционные, системы', keywords={' встраиваемые операционные системы', 'операционные системы'}),
#  KeywordGroup(mean='методы, повышения', keywords={' методы повышения фотореактивности'}),
#  KeywordGroup(mean='станок, сверлильный', keywords={' сверлильный станок', ' фрезерный станок', 'станки'}),
#  KeywordGroup(mean='ток, Электрический', keywords={'Электрический ток', ' синусоидальный ток', 'несинусоидальный ток'}),
#  KeywordGroup(mean='коэффициент, теплоотдачи', keywords={'коэффициент теплоотдачи', 'коэффициент летучести'}),
#  KeywordGroup(mean='области, оценки', keywords={' области оценки рисков информационной безопасности'}),
#  KeywordGroup(mean='характеристики, эмоции', keywords={'характеристики эмоции'}),
#  KeywordGroup(mean='автоматическое, управление', keywords={' автоматическое управление', 'Системы автоматического управления'}),
#  KeywordGroup(mean='архитектуры, информационных', keywords={' принципы построения архитектуры информационных систем ', ' информационная архитектура', ' построение архитектуры информационных систем'}),
#  KeywordGroup(mean='организация, работы', keywords={' организация работы волонтеров'}),
#  KeywordGroup(mean='защита, информации', keywords={'защита информации классификация шифров по', 'криптографическая защита информации классификация', 'криптографическая защита информации классификация шифров'}),
#  KeywordGroup(mean='химия, растворная', keywords={' химия', ' растворная химия'}),
#  KeywordGroup(mean='системное, мышление', keywords={' системное мышление'}),
#  KeywordGroup(mean='дискретная, математика', keywords={' дискретная математика'}),
#  KeywordGroup(mean='основные, этапы', keywords={'основные этапы разработки приложений', ' основные этапы разработки компилятора'}),
#  KeywordGroup(mean='бесцветное, стекло', keywords={'бесцветное стекло', ' оптическое бесцветное стекло'}),
#  KeywordGroup(mean='основы, природоохранных', keywords={'основы природоохранных биотехнологий'}),
#  KeywordGroup(mean='промышленный, дизайн', keywords={' промышленный дизайн'}),
#  KeywordGroup(mean='творческое, мышление', keywords={'психология творческого мышления', 'творческое рефлексивное мышление', ' творческое мышление'}),
#  KeywordGroup(mean='основные, понятия', keywords={' основные понятия', ' основные понятия документоведения', 'интернетжурналистика основные понятия'}),
#  KeywordGroup(mean='проектирование, процессов', keywords={' проектирование теплообменных процессов биотехнологии', ' проектирование массообменных процессов биотехнологии'}),
#  KeywordGroup(mean='обратная, связь', keywords={'обратная связь'}),
#  KeywordGroup(mean='спецификации', keywords={' спецификации'}),
#  KeywordGroup(mean='windows', keywords={' windows'}),
#  KeywordGroup(mean='структуры, управления', keywords={'  структуры управления проектами', ' организационные структуры управления проекта'}),
#  KeywordGroup(mean='управление, ключами', keywords={' управление криптографическими ключами управление', ' управление ключами'}),
#  KeywordGroup(mean='основные, требования', keywords={'основные требования проектирования итпроектов', ' основные требования к проектированию'}),
#  KeywordGroup(mean='ip, tcp', keywords={'ip', 'tcp ip'}),
#  KeywordGroup(mean='стабилизаторы', keywords={' стабилизаторы'}),
#  KeywordGroup(mean='динамическая, калибровка', keywords={' динамическая калибровка многозвенных робототехнических систем', ' динамическая калибровка'}),
#  KeywordGroup(mean='графические, методы', keywords={' графические методы', 'графический пайплайн'}),
#  KeywordGroup(mean='variable, calculation', keywords={'variable calculation'}),
#  KeywordGroup(mean='моделирования, бизнеспроцессов', keywords={'моделирования бизнеспроцессов методология ведения документооборота'}),
#  KeywordGroup(mean='algorithms, patterns', keywords={'algorithms patterns', 'memetic algorithms'}),
#  KeywordGroup(mean='белки', keywords={' белки'}),
#  KeywordGroup(mean='технологии, управления', keywords={'технологии управления бизнесом', ' технологии бизнеса'}),
#  KeywordGroup(mean='речи, нормы', keywords={' нормы разговорного стиля речи', ' разговорный стиль речи'}),
#  KeywordGroup(mean='социальные, проекты', keywords={'социальные проекты'}),
#  KeywordGroup(mean='управление, проектной', keywords={' управление проектной деятельностью', 'Проектная деятельность'}),
#  KeywordGroup(mean='безопасность, продуктов', keywords={' безопасность продуктов', 'безопасность пищевых продуктов'}),
#  KeywordGroup(mean='законодательство', keywords={' законодательство'}),
#  KeywordGroup(mean='эскиз', keywords={' эскиз'}),
#  KeywordGroup(mean='квазичастицы', keywords={'квазичастицы'}),
#  KeywordGroup(mean='для, моделирования', keywords={' программы для моделирования', 'алгоритмы программ', ' алгоритмы программ для моделирования'}),
#  KeywordGroup(mean='параметры, материалв', keywords={' параметры материалв', ' динамические параметры'}),
#  KeywordGroup(mean='формула, рэлеяджинса', keywords={' формула рэлеяджинса', ' формула тейлора'}),
#  KeywordGroup(mean='интегральное, преобразование', keywords={' интегральное преобразование'}),
#  KeywordGroup(mean='подписи, для', keywords={' электронные подписи для обеспечения целостности', ' лектронные подписи для обеспечения целостности'}),
#  KeywordGroup(mean='дисперсионный, анализ', keywords={' дисперсионный анализ'}),
#  KeywordGroup(mean='Античность', keywords={'Античность'}),
#  KeywordGroup(mean='катализаторы', keywords={'катализаторы'}),
#  KeywordGroup(mean='полимеры', keywords={'полимеры'}),
#  KeywordGroup(mean='целевая, аудитория', keywords={'целевая аудитория'}),
#  KeywordGroup(mean='оформления, технических', keywords={'оформления технических заданий декомпозировать функции', ' оформление технического задания'}),
#  KeywordGroup(mean='кинетика, катализа', keywords={' кинетика ферментативного катализа', ' кинетика ферментивного катализа'}),
#  KeywordGroup(mean='основы, языка', keywords={' основы языка моделирования', 'основы языка kotlin'}),
#  KeywordGroup(mean='электрические, сигналы', keywords={'электрические сигналы'}),
#  KeywordGroup(mean='оптический, объектив', keywords={' оптический объектив', 'объективы', ' юстировка объективов'}),
#  KeywordGroup(mean='голография', keywords={' голография'}),
#  KeywordGroup(mean='коммерциализация', keywords={'коммерциализация'}),
#  KeywordGroup(mean='mesh', keywords={' mesh'}),
#  KeywordGroup(mean='системы, типов', keywords={' системы типов scala', ' типы сторителлинга'}),
#  KeywordGroup(mean='оптическое, покрытие', keywords={' оптическое покрытие'}),
#  KeywordGroup(mean='аспекты, обмена', keywords={' аспекты обмена медицинской информацией', ' технологические аспекты обмена медицинской информацией'}),
#  KeywordGroup(mean='файловая, подсистема', keywords={' файловая подсистема'}),
#  KeywordGroup(mean='экспериментов, приемы', keywords={' приемы проведения экспериментов', ' проведение экспериментов'}),
#  KeywordGroup(mean='цвета', keywords={' цвета'}),
#  KeywordGroup(mean='обработка, результатов', keywords={' обработка их результатов', 'обработка результатов'}),
#  KeywordGroup(mean='фреймворк, rosetta', keywords={' фреймворк rosetta'}),
#  KeywordGroup(mean='реализация, устройств', keywords={'реализация устройств управления'}),
#  KeywordGroup(mean='контестносвободная, грамматика', keywords={' контестносвободная грамматика'}),
#  KeywordGroup(mean='для, повышения', keywords={'\nдля повышения эффективности компании', '\nдеятельности для повышения эффективности компании'}),
#  KeywordGroup(mean='испытания, сертификационные', keywords={' сертификационные испытания', ' определительные испытания', ' испытания'}),
#  KeywordGroup(mean='электрические, цепи', keywords={' электрические цепи', 'анализ линейных электрических цепей', 'линейные электрические цепи'}),
#  KeywordGroup(mean='атрибуты', keywords={' атрибуты'}),
#  KeywordGroup(mean='цепи, трехфазные', keywords={' цепи', ' трехфазные цепи'}),
#  KeywordGroup(mean='конфликтология', keywords={' конфликтология'}),
#  KeywordGroup(mean='маркетинг', keywords={'маркетинг'}),
#  KeywordGroup(mean='линейное, программирование', keywords={'  линейное программирование', 'методы линейного программирования'}),
#  KeywordGroup(mean='метод, глубокого', keywords={' метод глубокого обучения', 'глубокое обучение'}),
#  KeywordGroup(mean='экономические, потребности', keywords={' экономические потребности'}),
#  KeywordGroup(mean='оптические, устройства', keywords={'голографические оптические устройства', ' оптические устройства'}),
#  KeywordGroup(mean='бизнес, процессов', keywords={'бизнес процессы', 'модели бизнес процессов', 'реинжиниринг бизнес процессов'}),
#  KeywordGroup(mean='анимация', keywords={'анимация'}),
#  KeywordGroup(mean='анализ, дискриминантный', keywords={'дискриминантный анализ', 'регрессионный анализ'}),
#  KeywordGroup(mean='аэротехногенное, загрязнение', keywords={' аэротехногенное загрязнение'}),
#  KeywordGroup(mean='фотоны', keywords={' фотоны'}),
#  KeywordGroup(mean='spectrum, emission', keywords={' emission spectrum', 'spectrum'}),
#  KeywordGroup(mean='анализ, изображений', keywords={'анализ изображений'}),
#  KeywordGroup(mean='больших, массивов', keywords={'принципы обработки больших массивов данных', ' обработка больших массивов данных'}),
#  KeywordGroup(mean='упругости, теории', keywords={'теории упругости пластичности', ' теория упругости'}),
#  KeywordGroup(mean='технологии, управления', keywords={' технологии управления', ' технологии автоматизированного управления'}),
#  KeywordGroup(mean='численное, интегрирование', keywords={' численное интегрирование'}),
#  KeywordGroup(mean='Python', keywords={'Python'}),
#  KeywordGroup(mean='континуальный, интеграл', keywords={'континуальный интеграл', 'интегралы'}),
#  KeywordGroup(mean='безопасности, угрозы', keywords={'угрозы информационной безопасности', 'классификация угроз безопасности информации', 'угрозы безопасности', ' угрозы надежности безопасности', ' угроз безопасности информации', ' виды угроз безопасности информации'}),
#  KeywordGroup(mean='проектирование, технологической', keywords={' проектирование технологической оснастки', 'технологическая оснастка'}),
#  KeywordGroup(mean='качество, интерфейса', keywords={'качество интерфейса'}),
#  KeywordGroup(mean='управлениями, инвестиций', keywords={'управлениями инвестиций'}),
#  KeywordGroup(mean='перспективы, критической', keywords={' перспективы критической переоценки собственной позиции'}),
#  KeywordGroup(mean='исследования, световой', keywords={'исследования световой среды'}),
#  KeywordGroup(mean='блокчейн', keywords={' блокчейн'}),
#  KeywordGroup(mean='состояния, бизисные', keywords={' бизисные состояния квантовой оптики', ' квантовые состояния'}),
#  KeywordGroup(mean='methods, phenomenology', keywords={'methods phenomenology micro economic potential modeling', 'methods recurrent', 'methods varieties', ' numerical methods'}),
#  KeywordGroup(mean='обработка, результатов', keywords={' обработка результатов оптических измерений', ' обработка результатов технических измерений', ' обработка результатов измерений'}),
#  KeywordGroup(mean='конфликты', keywords={' конфликты'}),
#  KeywordGroup(mean='пищевые, процессы', keywords={' пищевые биотехнологические процессы', ' пищевые биотехнологические процессы экологии', ' пищевые процессы'}),
#  KeywordGroup(mean='энергии, преобразования', keywords={' термоэлектрическое преобразования энергии', 'прямое преобразование энергии', ' преобразование энергии', ' устройства прямого преобразования энергии'}),
#  KeywordGroup(mean='проверка, гипотез', keywords={'проверка гипотез'}),
#  KeywordGroup(mean='моделирование, мехатронных', keywords={' моделирование робототехических мехатронных модулей ', ' моделирование мехатронных модулей'}),
#  KeywordGroup(mean='электронные, ресурсы', keywords={' электронные ресурсы', ' электронные информационные ресурсы'}),
#  KeywordGroup(mean='поляризация', keywords={'поляризация'}),
#  KeywordGroup(mean='качество, изображения', keywords={' анализ качества изображений', ' качество изображения', ' качество изображения многозвенной оптикоцифровой системы'}),
#  KeywordGroup(mean='functions, basics', keywords={' basics functions', ' sociocultural functions', 'variable functions'}),
#  ...]

# %%
print(groups)
# Out:
# {0: {'полевые транзисторы'}, 1: {'переменные'}, 2: {'линеаризация динамической модели электропривода', ' линеаризация динамической модели'}, 3: {' принципы действия устройств', 'физические принципы действия', ' принцип действия', ' принципы действия оборудования', ' принцип действия преобразователей', ' физические принципы действия устройств', ' принцип действия приборов'}, 4: {' maps'}, 5: {'скорость распространения'}, 6: {' анализ свойств материалов', ' исследования теплофизических свойств материалов', 'расчет термодинамическим методом', ' термодинамические методы расчета свойств материалов', ' физикохимические свойства материала', 'свойства полимерных материалов', ' теплофизические свойства материалов', 'методы расчета свойств материалов', ' свойства материалов', ' свойства пищевых материалов', ' термодинамические методы расчета свойств', ' свойства конструкционных материалов'}, 7: {'виртуальная реальность', 'технологии виртуальной реальности'}, 8: {' износостойкость'}, 9: {'теплофизические измерения', 'спектрометрические методы измерения', ' теория квантовых измерений', 'формализм квантовой теории', 'оптические измерения', 'оптические методы измерения', 'квантовые измерения', 'методы измерений', ' линейноугольные измерения', 'квантовая теория', ' теории оптических измерений', ' методы оптических измерений'}, 10: {'память'}, 11: {'итеративное обучение', ' системы обучения'}, 12: {'численное дифференцирование функций', 'численные методы аппроксимации функции', 'численные методы дифференцирования и интегрирования функций', ' численные методы апроксимации табличных функций'}, 13: {' предприятия'}, 14: {'защита гидросферы'}, 15: {' внедрение инновационных информационных систем', ' методологии внедрения информационных систем'}, 16: {'эксперимент'}, 17: {'социальная психология малых групп', 'социальная психология групп'}, 18: {' статическое тестирование', ' системное статическое тестирование'}, 19: {' юридические аспекты интеллектуальной деятельности'}, 20: {' волны', ' рлоские монохроматические волны', 'фракталы волны', ' монохроматические волны'}, 21: {' экспериментальная физика'}, 22: {'нейронные сети', ' рекуррентные нейронные сети', ' оптимизация для нейронных сетей', ' свёрточные нейронные сети'}, 23: {' presentation identification', ' scenarios identification'}, 24: {' эффективность вычислительных алгоритмов', ' эффективность вычислительных схем'}, 25: {'методы анализа моделирования бизнеспроцессов', ' моделирование систем холодоснабжения', 'моделирование в blender', 'методы анализа', 'методы точностного анализа', 'анализ', ' моделирование САПР', ' анализ фурье', ' формализованные методы анализа', ' точностный анализ', 'методы моделирования'}, 26: {'indicators of manufacturability', 'equilibrium positions of dynamic systems', 'functions of complex variable', 'functioning of instruments and devices', 'theory of functions of complex', 'mechanical models of fabrics', 'optimization of neural network hyperparameters', 'quality indicators of optoelectronic devices', ' effectiveness of lighting solution', 'tuning of neural networks', ' automated design of optical', ' numerical methods of solving ode', '  computer modelling of optical', ' methods of solving pde', 'equilibrium positions of dynamic', 'features of application', 'basics of scaling', ' identification of performance characteristics', 'quantum statistics of social systems', ' calculation of optical systems'}, 27: {' критерий гурвица'}, 28: {' теория информации', ' квантовая теория информации'}, 29: {'автоматизированные информационно-управляющие системы'}, 30: {' основ архитектуры вычислительной техники', ' архитектуры вычислительной техники'}, 31: {'анализа текстовых данных', 'инструментарий анализа текстовых данных'}, 32: {' основные методы решения математических', 'Решение логических задач', ' основные методы решения математических задач', 'решение измерительных задач', ' способы решения задач', ' методы решения задач математического анализа', 'вероятностные методы реш ...

# %%
fname = f'clusters' \
            f'.v{params.v}' \
            f'.size_{len(df)}' \
            f'.{params.model}' \
            f'.json'

# %%
with open(DATA_PATH / 'results' / 'clusters' / fname, 'w', encoding='utf-8') as f:
    json.dump({
        'params': asdict(params),
        'clusters': [
            {
                'mean': g.mean,
                'keywords': list(g.keywords)
            } for g in keyword_groups
        ]
    }, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ## ...

# %%
[
    "пошение качества разработки",
    "качество технологий",
    "качество проекта",
    "оценка качества",
    "качество изображения",
    "качество системы",
    "качества безопасности"
]
# Out:
# ['пошение качества разработки',
#  'качество технологий',
#  'качество проекта',
#  'оценка качества',
#  'качество изображения',
#  'качество системы',
#  'качества безопасности']

# %%
counter[tokenizer.single_tokenize('качество')]
# Out:
# 72

# %%
counter[tokenizer.single_tokenize('безопасности')]
# Out:
# 112

# %%
['оценка качества', 'качество проекта', 'качества безопасности']
# Out:
# ['оценка качества', 'качество проекта', 'качества безопасности']

# %%
1 - softmax(list(map(counter.get, tokenizer.tokenize("качества безопасности"))))
# Out:
# array([1., 0.])

# %%
tokenizer.tokenize("качества безопасности")
# Out:
# [166, 979]

# %%
counter[tokenizer.single_tokenize('экспоненциальные')]
# Out:
# 2

# %%
counter[tokenizer.single_tokenize('методы')]
# Out:
# 398

# %%
list(map(counter.get, tokenizer.tokenize("теория баз данных")))
# Out:
# [129, 50, 192]

# %%
list(map(counter.get, tokenizer.tokenize("базы данных")))
# Out:
# [50, 192]

# %%
softmax(normalize([[2, 398]])[0])
# Out:
# array([0.26993304, 0.73006696])

# %%
cosine(keyword_to_embedding("методы измерений",), keyword_to_embedding("теплофизические измерения"))
# Out:
# 0.10602856682146211

# %%
softmax(_)
# Out:
# 1.0

# %%
keyword = "теплофизические измерения"
indexes = tokenizer.tokenize(keyword)
counts = list(map(counter.get, indexes))
vec = 1 - softmax(normalize([counts]))[0]
vec
# Out:
# array([0.65047708, 0.34952292])

# %%
normalize_(map(counter.get, tokenizer.tokenize("теплофизические измерения")))
# Out:
# array([0.03691275, 0.11073826])

# %%
keyword = "экспоненциальные методы анализа"
indexes = tokenizer.tokenize(keyword)
counts = list(map(counter.get, indexes))
vec = 1 - softmax(normalize([counts]))[0]
vec
# Out:
# array([0.80113259, 0.55386276, 0.64500465])

# %%
keyword = 'экспоненциальные методы анализа'
indexes = tokenizer.tokenize(keyword)
counts = list(map(counter.get, indexes))
# vec = 1 - softmax(normalize([counts]))[0]
vec = 1 - normalize_(counts)
vec
# Out:
# array([0.99832215, 0.33389262, 0.52181208])

# %%
indexes
# Out:
# [35288, 550, 1170]

# %%
tokenizer.default_index
# Out:
# 249333

# %%
tokenizer.single_tokenize('база')
# Out:
# 600

# %%
mn, mx = minmax(counter.values())
m = mx - mn

# %%
def normalize_(x):
    return np.array([max(mn, x_ - mn) / m for x_ in x])

# %%
normalize_([2, 398])
# Out:
# array([0.00167785, 0.66610738])

# %%
sum(counter.values())
# Out:
# 24785

# %%
normalize([normalize_(map(counter.get, tokenizer.tokenize("теплофизические измерения")))], norm='max')
# Out:
# array([[0.33333333, 1.        ]])

# %%
tokenizer.single_tokenize('теплофизические')
# Out:
# 84843
